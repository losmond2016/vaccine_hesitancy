# %% [markdown]
# ## Wave 1 Data Cleaning
#
# This notebook runs the process to clean the Wave 1 survey data. In order for any wave 1 modelling to be correctly applied to the wave 2 data, it is necessary to ensure that each variable's name and values are consistent with the corresponding variable in the wave 2 data.
#
# The cleaning process includes:
# - Deleting unnecessary variables
# - Recoding Non response as null, and deleting records with null values
# - Recoding values where necessary such that they will be consistent across the wave 1 and wave 2 data files.

# %% [markdown]
# **Variables of interest**
# As noted above, only certain variables will be retained for analysis. These are a set of demographic and attitudinal variables which are present in both the wave 1 and 2 survey data (so that a wave 1 model can be tested on the wave 2 dataset).
#
# The variables of interest are (see separate data dictionary for further info):
# - DEMAGE: Respondent Age
# - DEMREG: UK Region of residence
# - DEMSEX: Respondent Gender
# - DEMEDU: Respondent Education level
# - DEMWRK: Respondent Working status
# - DEMREL: Respondent religion
# - DEMINC: Respondent Income
# - COV_Shield: Have you been shielding because you are in a vulnerable group for coronavirus (COVID-19)?
# - COV_TRUST_1: What sources of information about coronavirus (COVID-19) do you trust? - National Television
# - COV_TRUST_2: What sources of information about coronavirus (COVID-19) do you trust? - Satellite/International television
# - COV_TRUST_3: What sources of information about coronavirus (COVID-19) do you trust? - Radio
# - COV_TRUST_4: What sources of information about coronavirus (COVID-19) do you trust? - Newspapers
# - COV_TRUST_5: What sources of information about coronavirus (COVID-19) do you trust? - Social media (Facebook, Twitter, etc)
# - COV_TRUST_6: What sources of information about coronavirus (COVID-19) do you trust? - National Public Health Authorities
# - COV_TRUST_7: What sources of information about coronavirus (COVID-19) do you trust? - Healthcare Workers
# - COV_TRUST_8: What sources of information about coronavirus (COVID-19) do you trust? - International health authorities
# - COV_TRUST_9: What sources of information about coronavirus (COVID-19) do you trust? - Government websites
# - COV_TRUST_10: What sources of information about coronavirus (COVID-19) do you trust? - The internet or search engines
# - COV_TRUST_11: What sources of information about coronavirus (COVID-19) do you trust? - Family and friends
# - COV_TRUST_12: What sources of information about coronavirus (COVID-19) do you trust? - Work, school, or college
# - COV_TRUST_13: What sources of information about coronavirus (COVID-19) do you trust? - Other
# - VAC_DEC: Are you currently responsible for decisions relating to the vaccination of children?
# - COV_VAC_SELF: If a new coronavirus (COVID-19) vaccine became available, would you accept the vaccine for yourself?
# - COV_KNOWL_1: Agree/Disagree - Washing hands with soap or sanitiser can help prevent the spread of coronavirus (COVID-19)
# - COV_KNOWL_2: Agree/Disagree - Staying in your own home and reducing contact with others can help protect you against catching coronavirus (COVID-19
# - COV_KNOWL_3: Agree/Disagree - Staying indoors and reducing contact with others can help protect others from catching coronavirus (COVID-19)
# - COV_KNOWL_4: Agree/Disagree - If you catch coronavirus (COVID-19), you can infect somebody else before you have developed symptoms
# - COV_KNOWL_5: Agree/Disagree - On average, before lockdown, someone with coronavirus (COVID-19) would have infected 2-3 other people
# - COV_KNOWL_6: Agree/Disagree - Treatments exist to prevent you catching coronavirus (COVID-19)
# - COV_KNOWL_7: Agree/Disagree - Coronavirus (COVID-19) may be caused by mobile network signals or mobile network towers
# - DREAD: Agree/Disagree - When I think about coronavirus (COVID-19), I find it difficult to think calmly about it and feel great dread or fear
# - ANX_1: Over the past three months I have been feeling - Calm
# - ANX_2: Over the past three months I have been feeling -  Tense
# - ANX_3: Over the past three months I have been feeling - Upset
# - ANX_4: Over the past three months I have been feeling - Relaxed
# - ANX_5: Over the past three months I have been feeling - Content
# - ANX_6: Over the past three months I have been feeling - Worried

# %%
# Importing Necessary Packages
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
# Importing data as pandas dataframe
df_wave1 = pd.read_csv("C:/Users/laure/Documents/lshtm_raw_data/COVID-19_wave_1.csv", encoding='latin')

# %%
# Printing value counts for each variable to get an understanding of the data.
for column in df_wave1.columns:
    print(column)
    print()
    print(df_wave1[column].value_counts())
    print()
    print()
    print("-------------------")
    print()
# Out:
# StartDate
#
# 27/09/2020 03:21    73
# 27/09/2020 03:37    70
# 27/09/2020 03:49    69
# 27/09/2020 03:47    67
# 27/09/2020 03:43    64
#                     ..
# 29/09/2020 00:06     1
# 29/09/2020 00:03     1
# 29/09/2020 00:13     1
# 29/09/2020 00:04     1
# 14/10/2020 04:40     1
# Name: StartDate, Length: 4568, dtype: int64
#
#
# -------------------
#
# EndDate
#
# 27/09/2020 03:39    68
# 27/09/2020 03:52    67
# 27/09/2020 03:40    60
# 27/09/2020 03:53    59
# 27/09/2020 03:49    59
#                     ..
# 28/09/2020 22:03     1
# 28/09/2020 22:42     1
# 28/09/2020 22:51     1
# 28/09/2020 23:09     1
# 14/10/2020 04:44     1
# Name: EndDate, Length: 4569, dtype: int64
#
#
# -------------------
#
# Status
#
# IP Address    17000
# Spam              2
# Name: Status, dtype: int64
#
#
# -------------------
#
# IPAddress
#
# 78.129.209.36     6
# 78.129.209.34     5
# 37.220.16.34      4
# 185.125.226.42    4
# 78.129.209.35     4
#                  ..
# 86.6.202.181      1
# 146.199.246.58    1
# 109.159.33.49     1
# 80.0.170.247      1
# 79.68.51.160      1
# Name: IPAddress, Length: 16420, dtype: int64
#
#
# -------------------
#
# Progress
#
# 100.0    17002
# Name: Progress, dtype: int64
#
#
# -------------------
#
# Duration__in_seconds_
#
# 247.0     78
# 253.0     75
# 282.0     74
# 230.0     73
# 289.0     73
#           ..
# 2175.0     1
# 2476.0     1
# 1171.0     1
# 2588.0     1
# 926.0      1
# Name: Duration__in_seconds_, Length: 1518, dtype: int64
#
#
# -------------------
#
# Finished
#
# True    17002
# Name: Finished, dtype: int64
#
#
# -------------------
#
# RecordedDate
#
# 27/09/2020 03:39    68
# 27/09/2020 03:52    67
# 27/09/2020 03:40    61
# 27/09/2020 03:49    60
# 27/09/2020 03:47    59
#                     ..
# 28/09/2020 22:42     1
# 28/09/2020 22:51     1
# 28/09/2020 23:09     1
# 28/09/2020 23:24     1
# 14/10/2020 04:44     1
# Name: RecordedDate, Length: 4563, dtype: int64
#
#
# -------------------
#
# ResponseId
#
# R_1rrg6Uw5JTucnGy    1
# R_11baymOYd34JtBW    1
# R_DvFH3ZC10BrdpVn    1
# R_2YnOGxCPCmGbDCS    1
# R_1FS3Jauq1bavmM5    1
#                     ..
# R_11Z2iRwKJ4PHPvY    1
# R_2Evgc7MRAvPyLn4    1
# R_1jPPbiOLbkE0ZGd    1
# R_AhWnGFCQkAQHuiR    1
# R_cMHFY2TBfwW64Mh    1
# Name: ResponseId, Length: 17002, dtype: int64
#
#
# -------------------
#
# RecipientLastName
#
# Series([], Name: RecipientLastName, dtype: int64)
#
#
# -------------------
#
# RecipientFirstName
#
# SW7     75
# BS16    36
# E1      34
# NG9     34
# E17     33
#         ..
# FK19     1
# KA16     1
# GY2      1
# RH18     1
# W1G      1
# Name: RecipientFirstName, Length: 2460, dtype: int64
#
#
# -------------------
#
# RecipientEmail
#
# 2459@na.com    75
# 257@na.com     36
# 729@na.com     34
# 1734@na.com    34
# 737@na.com     33
#                ..
# 885@na.com      1
# 1234@na.com     1
# 1020@na.com     1
# 2125@na.com     1
# 2690@na.com     1
# Name: RecipientEmail, Length: 2460, dtype: int64
#
#
# -------------------
#
# LocationLatitude
#
# 51.496399    853
# 51.506393    129
# 54.583298    123
# 51.348801    107
# 51.516403     88
#             ...
# 51.659103      1
# 53.570099      1
# 34.766693      1
# 58.465805      1
# 51.633301      1
# Name: LocationLatitude, Length: 2201, dtype: int64
#
#
# -------------------
#
# LocationLongitude
#
# -0.122406      853
# -0.020004      129
# -5.933304      123
# -0.032104      107
# -0.093002       88
#               ...
#  38.749207       1
# -1.234802        1
# -1.702698        1
#  103.831604      1
# -1.542801        1
# Name: LocationLongitude, Length: 2223, dtype: int64
#
#
# -------------------
#
# DistributionChannel
#
# anonymous    17002
# Name: DistributionChannel, dtype: int64
#
#
# -------------------
#
# UserLanguage
#
# EN    17002
# Name: UserLanguage, dtype: int64
#
#
# -------------------
#
# Postcode
#
# SW7     75
# BS16    36
# E1      34
# NG9     34
# E17     33
#         ..
# FK19     1
# KA16     1
# GY2      1
# RH18     1
# W1G      1
# Name: Postcode, Length: 2460, dtype: int64
#
#
# -------------------
#
# DEMAGE
#
# 65    422
# 20    375
# 40    357
# 35    351
# 30    350
#      ...
# 89      3
# 88      3
# 90      2
# 93      1
# 91      1
# Name: DEMAGE, Length: 76, dtype: int64
#
#
# -------------------
#
# DEMREG
#
# South East                  2356
# Greater London              2145
# North West                  1916
# West Midlands               1504
# East of England             1491
# Yorkshire and The Humber    1461
# South West                  1452
# Scotland                    1447
# East Midlands               1235
# Wales                        832
# North East                   719
# Northern Irelend             444
# Name: DEMREG, dtype: int64
#
#
# -------------------
#
# DEMSEX
#
# Female    8754
# Male      8207
# Other       41
# Name: DEMSEX, dtype: int64
#
#
# -------------------
#
# DEMEDU
#
# Undergraduate or postgraduate degree, or other professional qualification    7125
# 5+ GCSE, O-levels, 1 A level, or equivalents                                 2849
# 2+ A levels or equivalents                                                   2458
# 0-4 GCSE, O-levels, or equivalents                                           2049
# Other (e.g. vocational, foreign qualifications)                               924
# No academic qualifications                                                    771
# Apprenticeship                                                                591
# Do not wish to answer                                                         165
# Do not know                                                                    70
# Name: DEMEDU, dtype: int64
#
#
# -------------------
#
# DEMWRK
#
# Working full-time (including self-employed)             7380
# Retired                                                 3262
# Working part-time (including self-employed)             2961
# Looking after the home                                   933
# Unemployed                                               855
# Student                                                  849
# Unable to work (e.g. short- or long-term disability)     647
# Do not wish to answer                                    115
# Name: DEMWRK, dtype: int64
#
#
# -------------------
#
# DEMREL
#
# Christian                8376
# Atheist or agnostic      5115
# Other                    1346
# Do not wish to answer    1183
# Muslim                    537
# Hindu                     181
# Jewish                    145
# Buddhist                  119
# Name: DEMREL, dtype: int64
#
#
# -------------------
#
# DEMETH
#
# White: English/Welsh/Scottish/Northern Irish/British    14025
# White: Other white background                             840
# Black, African, Caribbean or Black British                414
# Asian or Asian British: Indian                            322
# White: Irish                                              223
# Asian or Asian British: Pakistani                         199
# Asian or Asian British: Other                             197
# Other                                                     170
# Do not wish to answer                                     155
# White and Asian or White and Asian British                139
# Asian or Asian British: Chinese                           134
# White and Black Caribbean                                 107
# White and Black African                                    77
# Name: DEMETH, dtype: int64
#
#
# -------------------
#
# DEMLAN
#
# English or Welsh         15816
# Other                      770
# Polish                     141
# Do not wish to answer       83
# Urdu                        77
# Bengali                     61
# Punjabi                     54
# Name: DEMLAN, dtype: int64
#
#
# -------------------
#
# DEMINC
#
# £15,000 to £24,999       3230
# £25,000 to £34,999       3023
# Under £15,000            2469
# £35,000 to £44,999       2269
# £45,000 to £54,999       1703
# £65,000 to £99,999       1427
# Do not wish to answer    1393
# £55,000 to £64,999       1022
# Over £100,000             466
# Name: DEMINC, dtype: int64
#
#
# -------------------
#
# COV_BEHAV_1
#
# Worn a face covering    16236
# #NULL!                    766
# Name: COV_BEHAV_1, dtype: int64
#
#
# -------------------
#
# COV_BEHAV_2
#
# Washed your hands with soap or hand sanitiser more frequently than last month    14463
# #NULL!                                                                            2539
# Name: COV_BEHAV_2, dtype: int64
#
#
# -------------------
#
# COV_BEHAV_3
#
# #NULL!                   11607
# Used public transport     5395
# Name: COV_BEHAV_3, dtype: int64
#
#
# -------------------
#
# COV_BEHAV_4
#
# Visited shops, supermarkets, restaurants, pubs and/or bars    14949
# #NULL!                                                         2053
# Name: COV_BEHAV_4, dtype: int64
#
#
# -------------------
#
# COV_BEHAV_5
#
# Visited friends or family members not living in the same house    9611
# #NULL!                                                            7391
# Name: COV_BEHAV_5, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHEN
#
# 7 to 12 months                                              5290
# 13 to 24 months                                             3281
# 4 to 6 months                                               2760
# Do not know                                                 1951
# More than 24 months                                         1793
# I do not think a COVID-19 vaccine will ever be available    1228
# 1 to 3 months                                                584
# Less than 1 month                                            115
# Name: COV_VAC_WHEN, dtype: int64
#
#
# -------------------
#
# COV_VAC_SELF
#
# Yes, definitely                    8254
# Unsure, but leaning towards yes    5541
# Unsure, but leaning towards no     1845
# No, definitely not                 1362
# Name: COV_VAC_SELF, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_1
#
# #NULL!                                                 10424
# I do not yet know enough about how safe it would be     6578
# Name: COV_VAC_WHY_1, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_2
#
# #NULL!                                               12794
# I do not yet know about how effective it would be     4208
# Name: COV_VAC_WHY_2, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_3
#
# #NULL!                                              16323
# I do not feel I am at risk of catching the virus      679
# Name: COV_VAC_WHY_3, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_4
#
# #NULL!                                                               14618
# I would want to wait until other people had been vaccinated first     2384
# Name: COV_VAC_WHY_4, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_5
#
# #NULL!                                                          16327
# I do not feel I would be seriously ill if I caught the virus      675
# Name: COV_VAC_WHY_5, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_6
#
# #NULL!                                                          16598
# I am confident there will be other effective treatments soon      404
# Name: COV_VAC_WHY_6, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_13
#
# #NULL!                                                                              16140
# I believe vaccines can give you the disease they are designed to protect against      862
# Name: COV_VAC_WHY_13, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_7
#
# #NULL!                                                                                                         16690
# I am confident that I have already acquired immunity (protection) through previous infection with the virus      312
# Name: COV_VAC_WHY_7, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_8
#
# #NULL!                                                                                    13430
# Approval/Development for the vaccine may be rushed and it may not be thoroughly tested     3572
# Name: COV_VAC_WHY_8, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_9
#
# #NULL!                  16612
# Other (please state)      390
# Name: COV_VAC_WHY_9, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_12
#
# #NULL!         16863
# Do not know      139
# Name: COV_VAC_WHY_12, dtype: int64
#
#
# -------------------
#
# COV_VAC_WHY_9_TEXT
#
# I don't like injections                                                                                                                                                          2
# I am scared                                                                                                                                                                      2
# Worried about side effects                                                                                                                                                       2
# Other people need it more than me                                                                                                                                                2
# i have no trust in a vaccine due to i do not trust what will go into it. i do not trust anything where bill gates is involved                                                    2
#                                                                                                                                                                                 ..
# I do not trust this government to have my best interest at heart in the rush to get a vaccinne                                                                                   1
# i have a needle phobia                                                                                                                                                           1
# Ethical reasons. I fear the vaccine may be dependent cell lines developed from the aborted pre-born.                                                                             1
# Scared of needles                                                                                                                                                                1
# I wouldnt want to be vaccinated with a new vaccine for anything, I would only be vaccinated against something that has a proven history and long term side effects are known    1
# Name: COV_VAC_WHY_9_TEXT, Length: 381, dtype: int64
#
#
# -------------------
#
# COV_VAC_OTHERS
#
# Yes, definitely                    9914
# Unsure, but leaning towards yes    4505
# Unsure, but leaning towards no     1580
# No, definitely not                 1003
# Name: COV_VAC_OTHERS, dtype: int64
#
#
# -------------------
#
# COV_SHIELD
#
# No             13317
# Yes             3339
# Do not know      346
# Name: COV_SHIELD, dtype: int64
#
#
# -------------------
#
# COV_POS_1
#
# No        10346
# #NULL!     6656
# Name: COV_POS_1, dtype: int64
#
#
# -------------------
#
# COV_POS_2
#
# #NULL!          16515
# Yes - myself      487
# Name: COV_POS_2, dtype: int64
#
#
# -------------------
#
# COV_POS_3
#
# #NULL!                                 16570
# Yes - family member in my household      432
# Name: COV_POS_3, dtype: int64
#
#
# -------------------
#
# COV_POS_4
#
# #NULL!                                      15248
# Yes - family member outside my household     1754
# Name: COV_POS_4, dtype: int64
#
#
# -------------------
#
# COV_POS_5
#
# #NULL!                                                        12287
# Yes - someone else (e.g.  a friend, a work colleague, etc)     4715
# Name: COV_POS_5, dtype: int64
#
#
# -------------------
#
# COV_TRUST_1
#
# National television    8746
# #NULL!                 8256
# Name: COV_TRUST_1, dtype: int64
#
#
# -------------------
#
# COV_TRUST_2
#
# #NULL!                                           15152
# Satellite / international television channels     1850
# Name: COV_TRUST_2, dtype: int64
#
#
# -------------------
#
# COV_TRUST_3
#
# #NULL!    13377
# Radio      3625
# Name: COV_TRUST_3, dtype: int64
#
#
# -------------------
#
# COV_TRUST_4
#
# #NULL!        13574
# Newspapers     3428
# Name: COV_TRUST_4, dtype: int64
#
#
# -------------------
#
# COV_TRUST_5
#
# #NULL!                                   15499
# Social media (Facebook, Twitter, etc)     1503
# Name: COV_TRUST_5, dtype: int64
#
#
# -------------------
#
# COV_TRUST_6
#
# National public health authorities (such as the NHS or Public Health England / Wales)    10294
# #NULL!                                                                                    6708
# Name: COV_TRUST_6, dtype: int64
#
#
# -------------------
#
# COV_TRUST_7
#
# #NULL!                11658
# Healthcare workers     5344
# Name: COV_TRUST_7, dtype: int64
#
#
# -------------------
#
# COV_TRUST_8
#
# #NULL!                                                                      10658
# International health authorities (such as The World Health Organization)     6344
# Name: COV_TRUST_8, dtype: int64
#
#
# -------------------
#
# COV_TRUST_9
#
# #NULL!                 10927
# Government websites     6075
# Name: COV_TRUST_9, dtype: int64
#
#
# -------------------
#
# COV_TRUST_10
#
# #NULL!                            15555
# The internet or search engines     1447
# Name: COV_TRUST_10, dtype: int64
#
#
# -------------------
#
# COV_TRUST_11
#
# #NULL!                15042
# Family and friends     1960
# Name: COV_TRUST_11, dtype: int64
#
#
# -------------------
#
# COV_TRUST_12
#
# #NULL!                      16042
# Work, school, or college      960
# Name: COV_TRUST_12, dtype: int64
#
#
# -------------------
#
# COV_TRUST_13
#
# #NULL!                    16628
# Other (please specify)      374
# Name: COV_TRUST_13, dtype: int64
#
#
# -------------------
#
# COV_TRUST_13_TEXT
#
# Scientists                                                                                                        12
# Scottish government                                                                                                8
# Scottish Government                                                                                                6
# BBC                                                                                                                6
# scientists                                                                                                         5
#                                                                                                                   ..
# none anymore, too much confusion everywhere, no one is reliable anymore, too many contradictions from everyone     1
# News websites e.g. BBC                                                                                             1
# Scientific Data                                                                                                    1
# BBC Web                                                                                                            1
# The world heath organisation (WHO)                                                                                 1
# Name: COV_TRUST_13_TEXT, Length: 322, dtype: int64
#
#
# -------------------
#
# COV_KNOWL_1
#
# Strongly agree       11138
# Tend to agree         4671
# Tend to disagree       559
# Do not know            391
# Strongly disagree      243
# Name: COV_KNOWL_1, dtype: int64
#
#
# -------------------
#
# COV_KNOWL_2
#
# Strongly agree       11147
# Tend to agree         4452
# Tend to disagree       685
# Do not know            376
# Strongly disagree      342
# Name: COV_KNOWL_2, dtype: int64
#
#
# -------------------
#
# COV_KNOWL_3
#
# Strongly agree       10564
# Tend to agree         4748
# Tend to disagree       812
# Do not know            468
# Strongly disagree      410
# Name: COV_KNOWL_3, dtype: int64
#
#
# -------------------
#
# COV_KNOWL_4
#
# Strongly agree       10795
# Tend to agree         4495
# Do not know            902
# Tend to disagree       535
# Strongly disagree      275
# Name: COV_KNOWL_4, dtype: int64
#
#
# -------------------
#
# COV_KNOWL_5
#
# Tend to agree        6800
# Strongly agree       5389
# Do not know          3042
# Tend to disagree     1197
# Strongly disagree     574
# Name: COV_KNOWL_5, dtype: int64
#
#
# -------------------
#
# COV_KNOWL_6
#
# Strongly disagree    7964
# Tend to disagree     3978
# Do not know          2326
# Tend to agree        1789
# Strongly agree        945
# Name: COV_KNOWL_6, dtype: int64
#
#
# -------------------
#
# COV_KNOWL_7
#
# Strongly disagree    12786
# Do not know           1437
# Tend to disagree      1370
# Tend to agree          818
# Strongly agree         591
# Name: COV_KNOWL_7, dtype: int64
#
#
# -------------------
#
# VAC_HES_1
#
# Strongly disagree    6614
# Tend to disagree     5080
# Do not know          2346
# Tend to agree        1949
# Strongly agree       1013
# Name: VAC_HES_1, dtype: int64
#
#
# -------------------
#
# VAC_HES_2
#
# Do not know          5302
# Tend to agree        4017
# Tend to disagree     3683
# Strongly disagree    2484
# Strongly agree       1516
# Name: VAC_HES_2, dtype: int64
#
#
# -------------------
#
# VAC_HES_3
#
# Strongly disagree    9807
# Tend to disagree     3582
# Tend to agree        1656
# Do not know          1047
# Strongly agree        910
# Name: VAC_HES_3, dtype: int64
#
#
# -------------------
#
# VAC_HES_4
#
# Tend to agree        5899
# Strongly agree       5542
# Do not know          2286
# Tend to disagree     1889
# Strongly disagree    1386
# Name: VAC_HES_4, dtype: int64
#
#
# -------------------
#
# VAC_HES_5
#
# Strongly agree       8748
# Tend to agree        5670
# Do not know          1059
# Tend to disagree     1023
# Strongly disagree     502
# Name: VAC_HES_5, dtype: int64
#
#
# -------------------
#
# VAC_DEC
#
# No     11683
# Yes     5319
# Name: VAC_DEC, dtype: int64
#
#
# -------------------
#
# VAC_CHI_REFUSE
#
# #NULL!         11683
# No              3759
# Yes              944
# Do not know      616
# Name: VAC_CHI_REFUSE, dtype: int64
#
#
# -------------------
#
# VAC_CHI_WHICH_1
#
# #NULL!                                                    16491
# The measles, mumps, and rubella combined vaccine (MMR)      511
# Name: VAC_CHI_WHICH_1, dtype: int64
#
#
# -------------------
#
# VAC_CHI_WHICH_2
#
# #NULL!                            16333
# The seasonal influenza vaccine      669
# Name: VAC_CHI_WHICH_2, dtype: int64
#
#
# -------------------
#
# VAC_CHI_WHICH_4
#
# #NULL!                                     16629
# The human papilloma virus vaccine (HPV)      373
# Name: VAC_CHI_WHICH_4, dtype: int64
#
#
# -------------------
#
# VAC_CHI_WHICH_5
#
# #NULL!                   16912
# Other, please specify       90
# Name: VAC_CHI_WHICH_5, dtype: int64
#
#
# -------------------
#
# VAC_CHI_WHICH_5_TEXT
#
# Covid                                                                                       5
# Coronavirus                                                                                 3
# All vaccines                                                                                3
# Bcg                                                                                         3
# coronavirus                                                                                 2
#                                                                                            ..
# Swine Flu is the only vaccine we declined as it seemed rushed.                              1
# unsure. I perfer older well known ine 70 80 90. Heard latter one one too many in one go.    1
# Covid-19 vaccine                                                                            1
# Covid 19 vaccine                                                                            1
# covid19                                                                                     1
# Name: VAC_CHI_WHICH_5_TEXT, Length: 63, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI
#
# #NULL!                             11683
# Yes, definitely                     2313
# Unsure, but leaning towards yes     1896
# Unsure, but leaning towards no       701
# No, definitely not                   409
# Name: COV_VAC_CHI, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_1
#
# #NULL!                                                 14644
# I do not yet know enough about how safe it would be     2358
# Name: COV_VAC_CHI_WHY_1, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_2
#
# #NULL!                                               15584
# I do not yet know about how effective it would be     1418
# Name: COV_VAC_CHI_WHY_2, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_3
#
# #NULL!                                                                 16689
# I do not feel children in my care are at risk of catching the virus      313
# Name: COV_VAC_CHI_WHY_3, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_4
#
# #NULL!                                                               16285
# I would want to wait until other people had been vaccinated first      717
# Name: COV_VAC_CHI_WHY_4, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_5
#
# #NULL!                                                                                    16731
# I do not feel that children in my care would be seriously ill if they caught the virus      271
# Name: COV_VAC_CHI_WHY_5, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_6
#
# #NULL!                                                          16842
# I am confident there will be other effective treatments soon      160
# Name: COV_VAC_CHI_WHY_6, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_11
#
# #NULL!                                                                                  16762
# I believe vaccines can give you the disease they are designed to protect you against      240
# Name: COV_VAC_CHI_WHY_11, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_7
#
# #NULL!                                                                                                                           16900
# I am confident that children in my care have already acquired immunity (protection) through previous infection with the virus      102
# Name: COV_VAC_CHI_WHY_7, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_8
#
# #NULL!                                                                                    15898
# Approval/Development for the vaccine may be rushed and it may not be thoroughly tested     1104
# Name: COV_VAC_CHI_WHY_8, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_9
#
# #NULL!                  16922
# Other (please state)       80
# Name: COV_VAC_CHI_WHY_9, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_10
#
# #NULL!         16959
# Do not know       43
# Name: COV_VAC_CHI_WHY_10, dtype: int64
#
#
# -------------------
#
# COV_VAC_CHI_WHY_9_TEXT
#
# I do not believe in vaccines                                                                                                                                                                                  2
# Would wait until the vaccine had been in general use for at least a few years.                                                                                                                                1
# I do not trust it. This is a man made virus set to thin out the population. There is no cure, there is no vaccine.                                                                                            1
# The government worship satan                                                                                                                                                                                  1
# Because vaccines are the cause of many human defects today and we are hearing that his new vaccine alters your DNA which is steering towards a slippery slope for humanity asif we were not on one already    1
#                                                                                                                                                                                                              ..
# Children in my care will be adults by the time the vaccine is available. Will be their choice                                                                                                                 1
# We dont need a vaccine for something that doesnt exist                                                                                                                                                      1
# I dont trust bill gates and his plans to depopulate                                                                                                                                                           1
# My little boy is autistic. I have read and heard that it might come from vaccines                                                                                                                             1
# I dont think its necessary                                                                                                                                                                                    1
# Name: COV_VAC_CHI_WHY_9_TEXT, Length: 78, dtype: int64
#
#
# -------------------
#
# FLU_VAC_OFF
#
# No             8940
# Yes            7629
# Do not know     433
# Name: FLU_VAC_OFF, dtype: int64
#
#
# -------------------
#
# FLU_VAC_COND
#
# Yes, definitely                    9852
# Unsure, but leaning towards yes    3092
# Unsure, but leaning towards no     2007
# No, definitely not                 1950
# #NULL!                              101
# Name: FLU_VAC_COND, dtype: int64
#
#
# -------------------
#
# FLU_VAC_OTH
#
# #NULL!                             9953
# Unsure, but leaning towards yes    2750
# Unsure, but leaning towards no     1716
# No, definitely not                 1445
# Yes, definitely                    1138
# Name: FLU_VAC_OTH, dtype: int64
#
#
# -------------------
#
# FLU_VAC_12
#
# #NULL!         9016
# Yes            5105
# No             2848
# Do not know      33
# Name: FLU_VAC_12, dtype: int64
#
#
# -------------------
#
# FLU_VAC_HES
#
# #NULL!                    9016
# No, I am not reluctant    6478
# Yes, I am reluctant       1077
# Do not know                431
# Name: FLU_VAC_HES, dtype: int64
#
#
# -------------------
#
# FLU_VAC_HES_WHY_1
#
# #NULL!                                                                                                                                 16344
# My GP practice or pharmacy has social distancing measures in place (such as staggered appointments or the two-metre rules enforced)      658
# Name: FLU_VAC_HES_WHY_1, dtype: int64
#
#
# -------------------
#
# FLU_VAC_HES_WHY_2
#
# #NULL!                                                                                              16602
# The flu vaccine is offered in a drive-through clinic where I would not have to get out of my car      400
# Name: FLU_VAC_HES_WHY_2, dtype: int64
#
#
# -------------------
#
# FLU_VAC_HES_WHY_3
#
# #NULL!                                    16686
# The flu vaccine was offered at my home      316
# Name: FLU_VAC_HES_WHY_3, dtype: int64
#
#
# -------------------
#
# FLU_VAC_HES_WHY_8
#
# #NULL!                  16958
# Other (please state)       44
# Name: FLU_VAC_HES_WHY_8, dtype: int64
#
#
# -------------------
#
# FLU_VAC_HES_WHY_10
#
# #NULL!               16582
# None of the above      420
# Name: FLU_VAC_HES_WHY_10, dtype: int64
#
#
# -------------------
#
# FLU_VAC_HES_WHY_8_TEXT
#
# if i were guaranteed not to  have side effects like i did before                                                                                1
# I do not want a flu vaccine                                                                                                                     1
# I am afraid the flu vaccine would make me ill                                                                                                   1
# The vaccine was offered with special guidance and instructions on how to properly self administer                                               1
# Nothing allergic to it                                                                                                                          1
# I take an allergic reaction to the flu jav                                                                                                      1
# I'm a wimp and don't know if the needle would hurt.                                                                                             1
# Flu vaccine is offered by my office                                                                                                             1
# If I didn't have a phobia about needles                                                                                                         1
# If it had no egg in it                                                                                                                          1
# don't know still unsure about any vaccines                                                                                                      1
# local town hall                                                                                                                                 1
# being able to get an appointment at the doctors                                                                                                 1
# It was guaranteed that the flu vaccine would prevent the flu that was around. this does not happen.                                             1
# NEED CONSULTANT TO ADVISE ME DUE TO TAKING METHATREXATE                                                                                         1
# Pharmacy                                                                                                                                        1
# If friends dont get ill with as in the past. Never had one and never had flu                                                                   1
# via work                                                                                                                                        1
# NOTHING WOULD MAKE ME HAVE IT                                                                                                                   1
# cant get appointment for anything                                                                                                               1
# On the advice of my GP                                                                                                                          1
# Unsure, I just feel unsure about going in to the surgery                                                                                        1
# Were it proven to efficacious in my age group. Believe its only 30-40 per cent effective                                                       1
# I do not have any vaccines since i was a student nurse back in the 60's . My immune system is very high                                         1
# if the flu vaccine covered all forms of flu virus                                                                                               1
# every time i get the flu jab i end up with the flu, since not getting the jab for 3yrs iv not had the flu                                       1
# I had the vaccine - 3 weeks later I was ill with dreadful flu ...... it simply does not work !                                                  1
# Due to the past flu injection reaction I would not consider having it anywhere                                                                  1
# It doesn't cause an issue with getting a coronavirus vaccine                                                                                    1
# I had any faith it works.                                                                                                                       1
# At a pharmacy                                                                                                                                   1
# I would have the vaccine if offered as a nasal spray rather than the injection.  I had a severe reaction to the injection aprox 7 years ago.    1
# Being allergy tested as didn't have it last year because of potential complications                                                             1
# having the vaccination at work (I work in the MoD) and I have confidence in them.                                                               1
# I believe all vaccines carry serious health risks.                                                                                              1
# if the vaccine was manufactured not using egg protein                                                                                           1
# If it was in tablet form                                                                                                                        1
# I have had it done at a small Boots branch - my GP appears to be closed to visitors                                                             1
# if i could be convinced i would be ok as i have had an adverse reaction before                                                                  1
# That there's a specific time slot, that's kept to                                                                                               1
# Name: FLU_VAC_HES_WHY_8_TEXT, dtype: int64
#
#
# -------------------
#
# MMR_VAC_CHI
#
# #NULL!                         16491
# Much more likely                 157
# Neither more or less likely      144
# A little more likely             128
# Much less likely                  37
# Do not know                       31
# A little less likely              14
# Name: MMR_VAC_CHI, dtype: int64
#
#
# -------------------
#
# ANX_1
#
# Somewhat       9109
# Very much      4233
# Not at all     3340
# Do not know     320
# Name: ANX_1, dtype: int64
#
#
# -------------------
#
# ANX_2
#
# Somewhat       7364
# Not at all     5402
# Very much      3960
# Do not know     276
# Name: ANX_2, dtype: int64
#
#
# -------------------
#
# ANX_3
#
# Not at all     7015
# Somewhat       6784
# Very much      2855
# Do not know     348
# Name: ANX_3, dtype: int64
#
#
# -------------------
#
# ANX_4
#
# Somewhat       8982
# Not at all     3974
# Very much      3741
# Do not know     305
# Name: ANX_4, dtype: int64
#
#
# -------------------
#
# ANX_5
#
# Somewhat       8994
# Not at all     4056
# Very much      3494
# Do not know     458
# Name: ANX_5, dtype: int64
#
#
# -------------------
#
# ANX_6
#
# Somewhat       8162
# Very much      5132
# Not at all     3453
# Do not know     255
# Name: ANX_6, dtype: int64
#
#
# -------------------
#
# DREAD
#
# Tend to disagree     5671
# Tend to agree        5643
# Strongly disagree    3242
# Strongly agree       1728
# Do not know           718
# Name: DREAD, dtype: int64
#
#
# -------------------
#
# Age
#
# 65+      3384
# 35-44    3037
# 45-54    3022
# 25-34    2945
# 55-64    2539
# 18-24    2005
# Name: Age, dtype: int64
#
#
# -------------------
#
# state
#
# 017f64904df9f3cd03e44f7371ff6620a6d5b3ebQ0000CAG00000247    2
# 3938437734c1a9507595c2ba896bfc188c2cf244Q00000AC0000023c    1
# 0d80d6cf962a84365272f3a4160d1dae95fcb7eaQ000BD4T00000230    1
# 1f3b34c0586c1a4d7a0bd3dfd061a61d75206754Q000BBRZ0000024a    1
# b028bee8eb06ba6d6149c0861d0e60efdceb6767Q000BBCW0000024f    1
#                                                            ..
# e163eeeea99732dc2054ef929523dbbe6a1e1adbQ0005L8J0000024e    1
# 81941babafba30bbce9472531d05eedb8da88bf4Q0005JX900000240    1
# 6c391b2ff5d98bf425b4d2e8e893003fb7640b1eQ0005ABE0000022b    1
# 1cf44abaef324ef71f8f2202f348679779841a59Q0005LNJ0000024d    1
# 75e381118da07bffda18c2dbec3f2e50f2f91be4Q0008ZJC0000024c    1
# Name: state, Length: 17001, dtype: int64
#
#
# -------------------
#
# Time_check
#
# 0.0    17002
# Name: Time_check, dtype: int64
#
#
# -------------------
#
# straight_COV_KNOWL_1
#
# 0.0    16794
# 1.0      208
# Name: straight_COV_KNOWL_1, dtype: int64
#
#
# -------------------
#
# straight_ANX
#
# 0.0    16951
# 1.0       51
# Name: straight_ANX, dtype: int64
#
#
# -------------------
#
# straight_VAC_HES
#
# 0.0    16816
# 1.0      186
# Name: straight_VAC_HES, dtype: int64
#
#
# -------------------
#
# straight_no
#
# 0.0    16664
# 1.0      231
# 2.0      107
# Name: straight_no, dtype: int64
#
#
# -------------------
#
# straight_rate
#
# 0.00    16664
# 0.13      231
# 0.25      107
# Name: straight_rate, dtype: int64
#
#
# -------------------

# %%
# Deleting unnecessary variables
deletion_list = ["StartDate",
"EndDate",
"Status",
"IPAddress",
"Progress",
"Duration__in_seconds_",
"Finished",
"RecordedDate",
"ResponseId",
"RecipientLastName",
"RecipientFirstName",
"RecipientEmail",
"LocationLatitude",
"LocationLongitude",
"DistributionChannel",
"UserLanguage",
"Postcode",
"COV_BEHAV_1",
"COV_BEHAV_2",
"COV_BEHAV_3",
"COV_BEHAV_4",
"COV_BEHAV_5",
"COV_VAC_WHEN",
"COV_VAC_WHY_1",
"COV_VAC_WHY_2",
"COV_VAC_WHY_3",
"COV_VAC_WHY_4",
"COV_VAC_WHY_5",
"COV_VAC_WHY_6",
"COV_VAC_WHY_13",
"COV_VAC_WHY_7",
"COV_VAC_WHY_8",
"COV_VAC_WHY_9",
"COV_VAC_WHY_12",
"COV_VAC_WHY_9_TEXT",
"COV_VAC_OTHERS",
"COV_POS_1",
"COV_POS_2",
"COV_POS_3",
"COV_POS_4",
"COV_POS_5",
"VAC_CHI_REFUSE",
"VAC_CHI_WHICH_1",
"VAC_CHI_WHICH_2",
"VAC_CHI_WHICH_4",
"VAC_CHI_WHICH_5",
"VAC_CHI_WHICH_5_TEXT",
"COV_VAC_CHI",
"COV_VAC_CHI_WHY_1",
"COV_VAC_CHI_WHY_2",
"COV_VAC_CHI_WHY_3",
"COV_VAC_CHI_WHY_4",
"COV_VAC_CHI_WHY_5",
"COV_VAC_CHI_WHY_6",
"COV_VAC_CHI_WHY_11",
"COV_VAC_CHI_WHY_7",
"COV_VAC_CHI_WHY_8",
"COV_VAC_CHI_WHY_9",
"COV_VAC_CHI_WHY_10",
"COV_VAC_CHI_WHY_9_TEXT",
"COV_TRUST_13_TEXT",
"FLU_VAC_OFF",
"FLU_VAC_COND",
"FLU_VAC_OTH",
"FLU_VAC_12",
"FLU_VAC_HES",
"FLU_VAC_HES_WHY_1",
"FLU_VAC_HES_WHY_2",
"FLU_VAC_HES_WHY_3",
"FLU_VAC_HES_WHY_8",
"FLU_VAC_HES_WHY_10",
"FLU_VAC_HES_WHY_8_TEXT",
"MMR_VAC_CHI",
"Age",
"state",
"Time_check",
"straight_COV_KNOWL_1",
"straight_ANX",
"straight_VAC_HES",
"straight_no",
"straight_rate", 
"VAC_HES_1",
"VAC_HES_2",
"VAC_HES_3",
"VAC_HES_4",
"VAC_HES_5",
"DEMETH"
]


df_wave1.drop(deletion_list, axis=1, inplace=True)

# %%
# Checking final variable list
df_wave1.columns
# Out:
# Index(['DEMAGE', 'DEMREG', 'DEMSEX', 'DEMEDU', 'DEMWRK', 'DEMREL', 'DEMLAN',
#        'DEMINC', 'COV_VAC_SELF', 'COV_SHIELD', 'COV_TRUST_1', 'COV_TRUST_2',
#        'COV_TRUST_3', 'COV_TRUST_4', 'COV_TRUST_5', 'COV_TRUST_6',
#        'COV_TRUST_7', 'COV_TRUST_8', 'COV_TRUST_9', 'COV_TRUST_10',
#        'COV_TRUST_11', 'COV_TRUST_12', 'COV_TRUST_13', 'COV_KNOWL_1',
#        'COV_KNOWL_2', 'COV_KNOWL_3', 'COV_KNOWL_4', 'COV_KNOWL_5',
#        'COV_KNOWL_6', 'COV_KNOWL_7', 'VAC_DEC', 'ANX_1', 'ANX_2', 'ANX_3',
#        'ANX_4', 'ANX_5', 'ANX_6', 'DREAD'],
#       dtype='object')

# %%
# Recoding values where necessary, so that values are consistent across both wave 1 and wave 2 data.
# Setting dictionaries to assign new labels to old labels.

region = {'East Midlands': "East Midlands",
'North East': "North East",
'North West': "North West",
'West Midlands': "West Midlands",
'South East': "South East",
'Northern Irelend': "Northern Ireland",
'Scotland': "Scotland",
'Wales': "Wales",
'Yorkshire and The Humber': "Yorkshire and The Humber",
'East of England': "East of England",
'Greater London': "Greater London",
'South West': "South West"
}

education = {'No academic qualifications': "No academic qualifications",
'0-4 GCSE, O-levels, or equivalents': "0-4 GCSE, O-levels, or equivalents",
'5+ GCSE, O-levels, 1 A level, or equivalents': "5+ GCSE, O-levels, 1 A level, or equivalents",
'Apprenticeship': "Apprenticeship",
'2+ A levels or equivalents': "2+ A levels or equivalents",
'Undergraduate or postgraduate degree, or other professional qualification': "Undergraduate or postgraduate degree",
'Other (e.g. vocational, foreign qualifications)': "Other",
'Do not know': "Do not know",
'Do not wish to answer': "Do not wish to answer",
}

work = {'Working full-time (including self-employed)': "Working full-time",
'Working part-time (including self-employed)': "Working part-time",
'Unemployed': "Unemployed",
'Student': "Student",
'Looking after the home': "Looking after the home",
'Retired': "Retired",
'Do not wish to answer': "Do not wish to answer",
'Unable to work (e.g. short- or long-term disability)': "Unable to work",
}

# %%
# Creating lists of variables for renaming, and the corresponding value dictionaries.
relabel_list = ["DEMREG",
"DEMEDU",
"DEMWRK"]

values_dict_list = [region, education, work]

# %%
for item1, item2 in list(zip(relabel_list, values_dict_list)): # Zipping variable and corresponding value dictionaries together
    new_name = item1 + '_new' # Creating a new variable name per variable for value relabelling.
    df_wave1[new_name] = df_wave1[item1].map(item2) # Mapping the new values onto the new variable
    df_wave1.drop(item1, axis=1, inplace=True) # Dropping the original variable
    df_wave1.rename(columns={new_name: item1}, inplace=True) # Relabelling the new variable to the original variable name for consistency

# %%
# Creating function to recode non-response values as null

def col_recode(x):
    """Function to recode survey non-response values as null
    
    :param x: Original row value for recoding.
    :return: Result of any necessary recoding.
    """
    
    
    if x == 'Do not wish to answer':
        result = np.nan
    elif x == 'Do not know':
        result = np.nan
    elif x == '#NULL!':
        result = 0
    else:
        result = x
    return result

# %%
# Applying the non-response to null recode across the whole data file.
df1 = df_wave1.applymap(col_recode)

# %%
# Dropping those records coded as 'Other' in the gender column, as there are so few cases (<1%) and any analysis will not be meaningful.
gender_filter = df1[df1['DEMSEX'] == 'Other']
df1.drop(gender_filter.index, axis=0, inplace=True)
df1['DEMSEX'].value_counts()
# Out:
# Female    8754
# Male      8207
# Name: DEMSEX, dtype: int64

# %%
# Dropping the language variable in its entirety, as the distribution is so skewed towards English/Welsh, therefore do not expect any meaningful analysis.
df1.drop(['DEMLAN'], axis=1, inplace=True)

# %%
# Preparing Categorical variables for dummification, by assigning to a dummy list.

vars_for_dummy = [
    "DEMREG",
    "DEMSEX",
    "DEMEDU",
    "DEMWRK",
    "DEMREL",
    "DEMINC",
    "COV_SHIELD",
    "COV_TRUST_1",
    "COV_TRUST_2",
    "COV_TRUST_3",
    "COV_TRUST_4",
    "COV_TRUST_5",
    "COV_TRUST_6",
    "COV_TRUST_7",
    "COV_TRUST_8",
    "COV_TRUST_9",
    "COV_TRUST_10",
    "COV_TRUST_11",
    "COV_TRUST_12",
    "COV_TRUST_13"]

# %%
# Recoding the vaccine decision responsibility variable from string to integer (i.e. creating a dummy variable)
decision_values = {'Yes': 1, 'No': 0}
df1['VAC_DEC_new'] = df1['VAC_DEC'].map(decision_values)
df1.drop(['VAC_DEC'], axis=1, inplace=True)
df1.rename(columns={'VAC_DEC_new': 'VAC_DEC'}, inplace=True)

# %%
# Preparing scale variables for recoding to integer values. Grouping each scale type into lists and creating value recode dictionaries.

knowledge_scale = ['COV_KNOWL_1', 'COV_KNOWL_2', 'COV_KNOWL_3', 'COV_KNOWL_4', 'COV_KNOWL_5', 
                   'COV_KNOWL_6', 'COV_KNOWL_7', 'DREAD']
knowledge_values = {'Strongly disagree': 1, 'Tend to disagree': 2, 'Tend to agree': 3, 'Strongly agree': 4}

emotion_scale = ['ANX_1', 'ANX_2', 'ANX_3', 'ANX_4', 'ANX_5', 'ANX_6']
emotion_values = {'Not at all': 1, 'Somewhat': 2, 'Very much': 3}

willingness_values = {'Yes, definitely': 1, 'Unsure, but leaning towards yes': 2, 
                      'Unsure, but leaning towards no': 3, 'No, definitely not': 4}

# %%
# Recoding the COV_VAC_SELF variable.
df1['COV_VAC_SELF_new'] = df1['COV_VAC_SELF'].map(willingness_values)
df1.drop(['COV_VAC_SELF'], axis=1, inplace=True)
df1.rename(columns={'COV_VAC_SELF_new': 'COV_VAC_SELF'}, inplace=True)

# %%
# Recoding the knowledge scale variables.
for column in knowledge_scale:
    new_name = column + '_new'
    df1[new_name] = df1[column].map(knowledge_values)
    df1.drop(column, axis=1, inplace=True)
    df1.rename(columns={new_name: column}, inplace=True)

# %%
# Recoding the emotional scale variables.
for column in emotion_scale:
    new_name = column + '_new'
    df1[new_name] = df1[column].map(emotion_values)
    df1.drop(column, axis=1, inplace=True)
    df1.rename(columns={new_name: column}, inplace=True)

# %%
# Dropping all null values across the dataset.
df1.dropna(inplace=True)

# %%
# Checking cleaned value counts, including as percentages, to identify if any further value recategorisation is required.
for column in df1.columns:
    print()
    print(column)
    print(df1[column].value_counts())
    print()
    print()
    print(column)
    print(df1[column].value_counts(normalize=True))
    print()
    print()
    print("---------")
# Out:
# DEMAGE
# 65    268
# 49    220
# 50    204
# 66    197
# 40    194
#      ...
# 87      4
# 86      3
# 89      2
# 88      1
# 90      1
# Name: DEMAGE, Length: 73, dtype: int64
#
#
# DEMAGE
# 65    0.027955
# 49    0.022948
# 50    0.021279
# 66    0.020549
# 40    0.020236
#         ...
# 87    0.000417
# 86    0.000313
# 89    0.000209
# 88    0.000104
# 90    0.000104
# Name: DEMAGE, Length: 73, dtype: float64
#
#
# ---------
#
# DEMSEX
# Male      4919
# Female    4668
# Name: DEMSEX, dtype: int64
#
#
# DEMSEX
# Male      0.513091
# Female    0.486909
# Name: DEMSEX, dtype: float64
#
#
# ---------
#
# DEMREL
# Christian              5114
# Atheist or agnostic    3221
# Other                   726
# Muslim                  278
# Hindu                   108
# Jewish                   77
# Buddhist                 63
# Name: DEMREL, dtype: int64
#
#
# DEMREL
# Christian              0.533431
# Atheist or agnostic    0.335976
# Other                  0.075728
# Muslim                 0.028998
# Hindu                  0.011265
# Jewish                 0.008032
# Buddhist               0.006571
# Name: DEMREL, dtype: float64
#
#
# ---------
#
# DEMINC
# £25,000 to £34,999    1880
# £15,000 to £24,999    1878
# £35,000 to £44,999    1463
# Under £15,000         1299
# £45,000 to £54,999    1111
# £65,000 to £99,999     959
# £55,000 to £64,999     693
# Over £100,000          304
# Name: DEMINC, dtype: int64
#
#
# DEMINC
# £25,000 to £34,999    0.196099
# £15,000 to £24,999    0.195890
# £35,000 to £44,999    0.152602
# Under £15,000         0.135496
# £45,000 to £54,999    0.115886
# £65,000 to £99,999    0.100031
# £55,000 to £64,999    0.072285
# Over £100,000         0.031710
# Name: DEMINC, dtype: float64
#
#
# ---------
#
# COV_SHIELD
# No     7568
# Yes    2019
# Name: COV_SHIELD, dtype: int64
#
#
# COV_SHIELD
# No     0.789402
# Yes    0.210598
# Name: COV_SHIELD, dtype: float64
#
#
# ---------
#
# COV_TRUST_1
# National television    5434
# 0                      4153
# Name: COV_TRUST_1, dtype: int64
#
#
# COV_TRUST_1
# National television    0.566809
# 0                      0.433191
# Name: COV_TRUST_1, dtype: float64
#
#
# ---------
#
# COV_TRUST_2
# 0                                                8380
# Satellite / international television channels    1207
# Name: COV_TRUST_2, dtype: int64
#
#
# COV_TRUST_2
# 0                                                0.8741
# Satellite / international television channels    0.1259
# Name: COV_TRUST_2, dtype: float64
#
#
# ---------
#
# COV_TRUST_3
# 0        7235
# Radio    2352
# Name: COV_TRUST_3, dtype: int64
#
#
# COV_TRUST_3
# 0        0.754668
# Radio    0.245332
# Name: COV_TRUST_3, dtype: float64
#
#
# ---------
#
# COV_TRUST_4
# 0             7424
# Newspapers    2163
# Name: COV_TRUST_4, dtype: int64
#
#
# COV_TRUST_4
# 0             0.774382
# Newspapers    0.225618
# Name: COV_TRUST_4, dtype: float64
#
#
# ---------
#
# COV_TRUST_5
# 0                                        8706
# Social media (Facebook, Twitter, etc)     881
# Name: COV_TRUST_5, dtype: int64
#
#
# COV_TRUST_5
# 0                                        0.908105
# Social media (Facebook, Twitter, etc)    0.091895
# Name: COV_TRUST_5, dtype: float64
#
#
# ---------
#
# COV_TRUST_6
# National public health authorities (such as the NHS or Public Health England / Wales)    6309
# 0                                                                                        3278
# Name: COV_TRUST_6, dtype: int64
#
#
# COV_TRUST_6
# National public health authorities (such as the NHS or Public Health England / Wales)    0.658079
# 0                                                                                        0.341921
# Name: COV_TRUST_6, dtype: float64
#
#
# ---------
#
# COV_TRUST_7
# 0                     6356
# Healthcare workers    3231
# Name: COV_TRUST_7, dtype: int64
#
#
# COV_TRUST_7
# 0                     0.662981
# Healthcare workers    0.337019
# Name: COV_TRUST_7, dtype: float64
#
#
# ---------
#
# COV_TRUST_8
# 0                                                                           5614
# International health authorities (such as The World Health Organization)    3973
# Name: COV_TRUST_8, dtype: int64
#
#
# COV_TRUST_8
# 0                                                                           0.585585
# International health authorities (such as The World Health Organization)    0.414415
# Name: COV_TRUST_8, dtype: float64
#
#
# ---------
#
# COV_TRUST_9
# 0                      5778
# Government websites    3809
# Name: COV_TRUST_9, dtype: int64
#
#
# COV_TRUST_9
# 0                      0.602691
# Government websites    0.397309
# Name: COV_TRUST_9, dtype: float64
#
#
# ---------
#
# COV_TRUST_10
# 0                                 8739
# The internet or search engines     848
# Name: COV_TRUST_10, dtype: int64
#
#
# COV_TRUST_10
# 0                                 0.911547
# The internet or search engines    0.088453
# Name: COV_TRUST_10, dtype: float64
#
#
# ---------
#
# COV_TRUST_11
# 0                     8473
# Family and friends    1114
# Name: COV_TRUST_11, dtype: int64
#
#
# COV_TRUST_11
# 0                     0.883801
# Family and friends    0.116199
# Name: COV_TRUST_11, dtype: float64
#
#
# ---------
#
# COV_TRUST_12
# 0                           9009
# Work, school, or college     578
# Name: COV_TRUST_12, dtype: int64
#
#
# COV_TRUST_12
# 0                           0.93971
# Work, school, or college    0.06029
# Name: COV_TRUST_12, dtype: float64
#
#
# ---------
#
# COV_TRUST_13
# 0                         9377
# Other (please specify)     210
# Name: COV_TRUST_13, dtype: int64
#
#
# COV_TRUST_13
# 0                         0.978095
# Other (please specify)    0.021905
# Name: COV_TRUST_13, dtype: float64
#
#
# ---------
#
# DEMREG
# South East                  1363
# Greater London              1106
# North West                  1077
# South West                   848
# Scotland                     845
# East of England              842
# West Midlands                834
# Yorkshire and The Humber     812
# East Midlands                706
# Wales                        483
# North East                   415
# Northern Ireland             256
# Name: DEMREG, dtype: int64
#
#
# DEMREG
# South East                  0.142172
# Greater London              0.115365
# North West                  0.112340
# South West                  0.088453
# Scotland                    0.088140
# East of England             0.087827
# West Midlands               0.086993
# Yorkshire and The Humber    0.084698
# East Midlands               0.073641
# Wales                       0.050381
# North East                  0.043288
# Northern Ireland            0.026703
# Name: DEMREG, dtype: float64
#
#
# ---------
#
# DEMEDU
# Undergraduate or postgraduate degree            4423
# 5+ GCSE, O-levels, 1 A level, or equivalents    1584
# 2+ A levels or equivalents                      1364
# 0-4 GCSE, O-levels, or equivalents              1028
# Other                                            490
# Apprenticeship                                   351
# No academic qualifications                       347
# Name: DEMEDU, dtype: int64
#
#
# DEMEDU
# Undergraduate or postgraduate degree            0.461354
# 5+ GCSE, O-levels, 1 A level, or equivalents    0.165224
# 2+ A levels or equivalents                      0.142276
# 0-4 GCSE, O-levels, or equivalents              0.107229
# Other                                           0.051111
# Apprenticeship                                  0.036612
# No academic qualifications                      0.036195
# Name: DEMEDU, dtype: float64
#
#
# ---------
#
# DEMWRK
# Working full-time         4420
# Retired                   2036
# Working part-time         1599
# Looking after the home     496
# Student                    374
# Unemployed                 366
# Unable to work             296
# Name: DEMWRK, dtype: int64
#
#
# DEMWRK
# Working full-time         0.461041
# Retired                   0.212371
# Working part-time         0.166788
# Looking after the home    0.051737
# Student                   0.039011
# Unemployed                0.038177
# Unable to work            0.030875
# Name: DEMWRK, dtype: float64
#
#
# ---------
#
# VAC_DEC
# 0    6470
# 1    3117
# Name: VAC_DEC, dtype: int64
#
#
# VAC_DEC
# 0    0.674872
# 1    0.325128
# Name: VAC_DEC, dtype: float64
#
#
# ---------
#
# COV_VAC_SELF
# 1    5388
# 2    2874
# 3     773
# 4     552
# Name: COV_VAC_SELF, dtype: int64
#
#
# COV_VAC_SELF
# 1    0.562011
# 2    0.299781
# 3    0.080630
# 4    0.057578
# Name: COV_VAC_SELF, dtype: float64
#
#
# ---------
#
# COV_KNOWL_1
# 4.0    6786
# 3.0    2399
# 2.0     288
# 1.0     114
# Name: COV_KNOWL_1, dtype: int64
#
#
# COV_KNOWL_1
# 4.0    0.707834
# 3.0    0.250235
# 2.0    0.030041
# 1.0    0.011891
# Name: COV_KNOWL_1, dtype: float64
#
#
# ---------
#
# COV_KNOWL_2
# 4.0    6897
# 3.0    2203
# 2.0     335
# 1.0     152
# Name: COV_KNOWL_2, dtype: int64
#
#
# COV_KNOWL_2
# 4.0    0.719412
# 3.0    0.229790
# 2.0    0.034943
# 1.0    0.015855
# Name: COV_KNOWL_2, dtype: float64
#
#
# ---------
#
# COV_KNOWL_3
# 4.0    6565
# 3.0    2429
# 2.0     401
# 1.0     192
# Name: COV_KNOWL_3, dtype: int64
#
#
# COV_KNOWL_3
# 4.0    0.684781
# 3.0    0.253364
# 2.0    0.041827
# 1.0    0.020027
# Name: COV_KNOWL_3, dtype: float64
#
#
# ---------
#
# COV_KNOWL_4
# 4.0    6844
# 3.0    2306
# 2.0     295
# 1.0     142
# Name: COV_KNOWL_4, dtype: int64
#
#
# COV_KNOWL_4
# 4.0    0.713883
# 3.0    0.240534
# 2.0    0.030771
# 1.0    0.014812
# Name: COV_KNOWL_4, dtype: float64
#
#
# ---------
#
# COV_KNOWL_5
# 3.0    4570
# 4.0    3897
# 2.0     772
# 1.0     348
# Name: COV_KNOWL_5, dtype: int64
#
#
# COV_KNOWL_5
# 3.0    0.476687
# 4.0    0.406488
# 2.0    0.080526
# 1.0    0.036299
# Name: COV_KNOWL_5, dtype: float64
#
#
# ---------
#
# COV_KNOWL_6
# 1.0    5431
# 2.0    2511
# 3.0    1063
# 4.0     582
# Name: COV_KNOWL_6, dtype: int64
#
#
# COV_KNOWL_6
# 1.0    0.566496
# 2.0    0.261917
# 3.0    0.110879
# 4.0    0.060707
# Name: COV_KNOWL_6, dtype: float64
#
#
# ---------
#
# COV_KNOWL_7
# 1.0    7989
# 2.0     699
# 3.0     510
# 4.0     389
# Name: COV_KNOWL_7, dtype: int64
#
#
# COV_KNOWL_7
# 1.0    0.833316
# 2.0    0.072911
# 3.0    0.053197
# 4.0    0.040576
# Name: COV_KNOWL_7, dtype: float64
#
#
# ---------
#
# DREAD
# 2.0    3360
# 3.0    3325
# 1.0    1874
# 4.0    1028
# Name: DREAD, dtype: int64
#
#
# DREAD
# 2.0    0.350475
# 3.0    0.346824
# 1.0    0.195473
# 4.0    0.107229
# Name: DREAD, dtype: float64
#
#
# ---------
#
# ANX_1
# 2.0    5239
# 3.0    2504
# 1.0    1844
# Name: ANX_1, dtype: int64
#
#
# ANX_1
# 2.0    0.546469
# 3.0    0.261187
# 1.0    0.192344
# Name: ANX_1, dtype: float64
#
#
# ---------
#
# ANX_2
# 2.0    4185
# 1.0    3198
# 3.0    2204
# Name: ANX_2, dtype: int64
#
#
# ANX_2
# 2.0    0.436529
# 1.0    0.333577
# 3.0    0.229895
# Name: ANX_2, dtype: float64
#
#
# ---------
#
# ANX_3
# 1.0    4211
# 2.0    3846
# 3.0    1530
# Name: ANX_3, dtype: int64
#
#
# ANX_3
# 1.0    0.439241
# 2.0    0.401168
# 3.0    0.159591
# Name: ANX_3, dtype: float64
#
#
# ---------
#
# ANX_4
# 2.0    5207
# 3.0    2202
# 1.0    2178
# Name: ANX_4, dtype: int64
#
#
# ANX_4
# 2.0    0.543131
# 3.0    0.229686
# 1.0    0.227183
# Name: ANX_4, dtype: float64
#
#
# ---------
#
# ANX_5
# 2.0    5290
# 1.0    2247
# 3.0    2050
# Name: ANX_5, dtype: int64
#
#
# ANX_5
# 2.0    0.551789
# 1.0    0.234380
# 3.0    0.213831
# Name: ANX_5, dtype: float64
#
#
# ---------
#
# ANX_6
# 2.0    4673
# 3.0    2940
# 1.0    1974
# Name: ANX_6, dtype: int64
#
#
# ANX_6
# 2.0    0.487431
# 3.0    0.306665
# 1.0    0.205904
# Name: ANX_6, dtype: float64
#
#
# ---------

# %%
# Recategorising the religion variable so that those religions making <5% of sample are grouped into 'other' category.
df1['DEMREL'] = df1['DEMREL'].apply(lambda x: 'Other' if (x == 'Hindu' or x == 'Jewish' or x == 'Buddhist') else x)

# %%
# Creating two extra binary target variables ('yes', or 'no') for use in modelling. Target 1 only includes those 'definitely yes' or 'definitely no'. Target 2 groups those 'unsure' into those categories into which they are leaning.

df1['target_1'] = df1['COV_VAC_SELF'].apply(lambda x: 1 if x == 1 else 0 if x == 4 else np.nan)
df1['target_2'] = df1['COV_VAC_SELF'].apply(lambda x: 1 if (x == 1 or x == 2) else 0 if (x == 3 or x == 4) else np.nan)

# %%
# Dummifying the dataset
wave1 = pd.get_dummies(df1, columns=vars_for_dummy)

# %%
# Getting summary of dummifyed variables
wave1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9587 entries, 1 to 17000
# Data columns (total 87 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   DEMAGE                                                                                             9587 non-null   int64
#  1   VAC_DEC                                                                                            9587 non-null   int64
#  2   COV_VAC_SELF                                                                                       9587 non-null   int64
#  3   COV_KNOWL_1                                                                                        9587 non-null   float64
#  4   COV_KNOWL_2                                                                                        9587 non-null   float64
#  5   COV_KNOWL_3                                                                                        9587 non-null   float64
#  6   COV_KNOWL_4                                                                                        9587 non-null   float64
#  7   COV_KNOWL_5                                                                                        9587 non-null   float64
#  8   COV_KNOWL_6                                                                                        9587 non-null   float64
#  9   COV_KNOWL_7                                                                                        9587 non-null   float64
#  10  DREAD                                                                                              9587 non-null   float64
#  11  ANX_1                                                                                              9587 non-null   float64
#  12  ANX_2                                                                                              9587 non-null   float64
#  13  ANX_3                                                                                              9587 non-null   float64
#  14  ANX_4                                                                                              9587 non-null   float64
#  15  ANX_5                                                                                              9587 non-null   float64
#  16  ANX_6                                                                                              9587 non-null   float64
#  17  target_1                                                                                           5940 non-null   float64
#  18  target_2                                                                                           9587 non-null   int64
#  19  DEMREG_East Midlands                                                                               9587 non-null   uint8
#  20  DEMREG_East of England                                                                             9587 non-null   uint8
#  21  DEMREG_Greater London                                                                              9587 non-null   uint8
#  22  DEMREG_North East                                                                                  9587 non-null   uint8
#  23  DEMREG_North West                                                                                  9587 non-null   uint8
#  24  DEMREG_Northern Ireland                                                                            9587 non-null   uint8
#  25  DEMREG_Scotland                                                                                    9587 non-null   uint8
#  26  DEMREG_South East                                                                                  9587 non-null   uint8
#  27  DEMREG_South West                                                                                  9587 non-null   uint8
#  28  DEMREG_Wales                                                                                       9587 non-null   uint8
#  29  DEMREG_West Midlands                                                                               9587 non-null   uint8
#  30  DEMREG_Yorkshire and The Humber                                                                    9587 non-null   uint8
#  31  DEMSEX_Female                                                                                      9587 non-null   uint8
#  32  DEMSEX_Male                                                                                        9587 non-null   uint8
#  33  DEMEDU_0-4 GCSE, O-levels, or equivalents                                                          9587 non-null   uint8
#  34  DEMEDU_2+ A levels or equivalents                                                                  9587 non-null   uint8
#  35  DEMEDU_5+ GCSE, O-levels, 1 A level, or equivalents                                                9587 non-null   uint8
#  36  DEMEDU_Apprenticeship                                                                              9587 non-null   uint8
#  37  DEMEDU_No academic qualifications                                                                  9587 non-null   uint8
#  38  DEMEDU_Other                                                                                       9587 non-null   uint8
#  39  DEMEDU_Undergraduate or postgraduate degree                                                        9587 non-null   uint8
#  40  DEMWRK_Looking after the home                                                                      9587 non-null   uint8
#  41  DEMWRK_Retired                                                                                     9587 non-null   uint8
#  42  DEMWRK_Student                                                                                     9587 non-null   uint8
#  43  DEMWRK_Unable to work                                                                              9587 non-null   uint8
#  44  DEMWRK_Unemployed                                                                                  9587 non-null   uint8
#  45  DEMWRK_Working full-time                                                                           9587 non-null   uint8
#  46  DEMWRK_Working part-time                                                                           9587 non-null   uint8
#  47  DEMREL_Atheist or agnostic                                                                         9587 non-null   uint8
#  48  DEMREL_Christian                                                                                   9587 non-null   uint8
#  49  DEMREL_Muslim                                                                                      9587 non-null   uint8
#  50  DEMREL_Other                                                                                       9587 non-null   uint8
#  51  DEMINC_Over £100,000                                                                               9587 non-null   uint8
#  52  DEMINC_Under £15,000                                                                               9587 non-null   uint8
#  53  DEMINC_£15,000 to £24,999                                                                          9587 non-null   uint8
#  54  DEMINC_£25,000 to £34,999                                                                          9587 non-null   uint8
#  55  DEMINC_£35,000 to £44,999                                                                          9587 non-null   uint8
#  56  DEMINC_£45,000 to £54,999                                                                          9587 non-null   uint8
#  57  DEMINC_£55,000 to £64,999                                                                          9587 non-null   uint8
#  58  DEMINC_£65,000 to £99,999                                                                          9587 non-null   uint8
#  59  COV_SHIELD_No                                                                                      9587 non-null   uint8
#  60  COV_SHIELD_Yes                                                                                     9587 non-null   uint8
#  61  COV_TRUST_1_0                                                                                      9587 non-null   uint8
#  62  COV_TRUST_1_National television                                                                    9587 non-null   uint8
#  63  COV_TRUST_2_0                                                                                      9587 non-null   uint8
#  64  COV_TRUST_2_Satellite / international television channels                                          9587 non-null   uint8
#  65  COV_TRUST_3_0                                                                                      9587 non-null   uint8
#  66  COV_TRUST_3_Radio                                                                                  9587 non-null   uint8
#  67  COV_TRUST_4_0                                                                                      9587 non-null   uint8
#  68  COV_TRUST_4_Newspapers                                                                             9587 non-null   uint8
#  69  COV_TRUST_5_0                                                                                      9587 non-null   uint8
#  70  COV_TRUST_5_Social media (Facebook, Twitter, etc)                                                  9587 non-null   uint8
#  71  COV_TRUST_6_0                                                                                      9587 non-null   uint8
#  72  COV_TRUST_6_National public health authorities (such as the NHS or Public Health England / Wales)  9587 non-null   uint8
#  73  COV_TRUST_7_0                                                                                      9587 non-null   uint8
#  74  COV_TRUST_7_Healthcare workers                                                                     9587 non-null   uint8
#  75  COV_TRUST_8_0                                                                                      9587 non-null   uint8
#  76  COV_TRUST_8_International health authorities (such as The World Health Organization)               9587 non-null   uint8
#  77  COV_TRUST_9_0                                                                                      9587 non-null   uint8
#  78  COV_TRUST_9_Government websites                                                                    9587 non-null   uint8
#  79  COV_TRUST_10_0                                                                                     9587 non-null   uint8
#  80  COV_TRUST_10_The internet or search engines                                                        9587 non-null   uint8
#  81  COV_TRUST_11_0                                                                                     9587 non-null   uint8
#  82  COV_TRUST_11_Family and friends                                                                    9587 non-null   uint8
#  83  COV_TRUST_12_0                                                                                     9587 non-null   uint8
#  84  COV_TRUST_12_Work, school, or college                                                              9587 non-null   uint8
#  85  COV_TRUST_13_0                                                                                     9587 non-null   uint8
#  86  COV_TRUST_13_Other (please specify)                                                                9587 non-null   uint8
# dtypes: float64(15), int64(4), uint8(68)
# memory usage: 2.1 MB

# %%
# SAVING DUMMY AND NON DUMMY DATAFILES

# %%
# Saving non dummy dataframe to csv for use in subsequent analysis
df1.to_csv("C:/Users/laure/Documents/vaccine_hesitancy_and_uptake/1_data_cleaning/wave_1_vaccine_intention_data_nondum.csv")

# %%
# Saving dummified dataframe to csv for use in subsequent analysis
wave1.to_csv("C:/Users/laure/Documents/vaccine_hesitancy_and_uptake/1_data_cleaning/wave_1_vaccine_intention_data.csv")
